# %% [markdown]
# ## Caracterización

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

data = "Datos_Icte_n.xlsx"
data = pd.read_excel(data)
data
# Out:
#     CorrienteCampo (A)  B (mT)  B_err (mT)  B_rounded (mT)  \
# 0                 -1.4 -321.16    0.135558         -321.20
# 1                 -1.2 -275.45    0.119013         -275.50
# 2                 -1.0 -229.74    0.102956         -229.70
# 3                 -0.8 -184.03    0.087658         -184.03
# 4                 -0.6 -138.32    0.073593         -138.32
# 5                 -0.4  -92.61    0.061612          -92.61
# 6                 -0.2  -46.90    0.053141          -46.90
# 7                  0.0   -1.19    0.050000           -1.19
# 8                  0.2   44.52    0.053141           44.52
# 9                  0.4   90.23    0.061612           90.23
# 10                 0.6  135.94    0.073593          135.94
# 11                 0.8  181.65    0.087658          181.65
# 12                 1.0  227.36    0.102956          227.40
# 13                 1.2  273.07    0.119013          273.10
# 14                 1.4  318.78    0.135558          318.80
#
#     B_err_rounded (mT)  VH_-20mA (mV)  VH_-10mA (mV)  VH_10mA (mV)  \
# 0                 0.10          -36.7          -18.4          16.7
# 1                 0.10          -31.7          -15.7          14.4
# 2                 0.10          -25.6          -12.7          12.2
# 3                 0.09          -19.8           -9.6          10.0
# 4                 0.07          -13.9           -6.6           7.6
# 5                 0.06           -8.2           -3.9           5.0
# 6                 0.05           -2.1           -1.2           2.7
# 7                 0.05            4.0            1.8           0.5
# 8                 0.05            9.3            5.1          -1.6
# 9                 0.06           14.9            8.2          -4.0
# 10                0.07           20.7           11.2          -6.3
# 11                0.09           26.5           14.3          -8.6
# 12                0.10           32.3           17.4         -11.1
# 13                0.10           37.6           20.3         -13.3
# 14                0.10           43.0           23.3         -15.5
#
#     VH_20mA (mV)  VH_err (mV)
# 0           35.5          0.1
# 1           30.3          0.1
# 2           25.1          0.1
# 3           20.2          0.1
# 4           14.9          0.1
# 5            9.9          0.1
# 6            4.8          0.1
# 7            0.9          0.1
# 8           -4.4          0.1
# 9           -9.6          0.1
# 10         -14.9          0.1
# 11         -19.6          0.1
# 12         -24.7          0.1
# 13         -29.5          0.1
# 14         -34.8          0.1

# %%
X = data['B_rounded (mT)']
Xerr = data['B_err_rounded (mT)']

Y = data['VH_-20mA (mV)']
Yerr = data['VH_err (mV)']

w = 1/(Yerr**2)

# %%
sum_w = w.sum()
sum_wx = (w*X).sum()
sum_wy = (w*Y).sum()
sum_wxx = (w*X**2).sum()
sum_wxy = (w*X*Y).sum()

# %%
m = (sum_w*sum_wxy - sum_wx*sum_wy) / (sum_w*sum_wxx - sum_wx**2)
b = (sum_wxx*sum_wy - sum_wx*sum_wxy) / (sum_w*sum_wxx - sum_wx**2)

m_std_err = np.sqrt(sum_w/(sum_w*sum_wxx-sum_wx**2))
b_std_err = np.sqrt(sum_wxx/(sum_w*sum_wxx-sum_wx**2))

# %%
print(m)
print(b)

print(m_std_err)
print(b_std_err)
# Out:
# 0.1257685723679284
# 3.5026625515915173
# 0.00013073119253263727
# 0.025820355543282828

# %%
model1 = (0.1258)*X + (3.50)

# %%
plt.errorbar(X, Y, Yerr, Xerr,  fmt='o')
plt.plot(X, model1, color = 'red', linestyle='--')
plt.title('Voltaje de Hall vs. Campo Magnético con ' + r'$I_p = -20mA$' + ' (Germanio n)')
plt.xlabel('Campo Magnético (mT)')
plt.ylabel('Voltaje de Hall (mV)')
plt.savefig('Icte_n_-20mA.png', format='png')

# %%
res = (Y - model1)/Yerr

fig2, (ax2) = plt.subplots(1, 1)

ax2.scatter(X, res)
ax2.axhline(0, color='green', linewidth=1, linestyle='--')

ax2.set_xlabel('Campo Magnético (mT)')
ax2.set_ylabel('Voltaje de Hall (mV)')
ax2.set_title('Residuales para Voltaje de Hall vs. Campo Magnético con ' + r'$I_p = -20mA$' + ' (Germanio n)')
ax2.grid()

plt.savefig('Icte_n_-20mA_residual.png', format='png')

# %%
Y = data['VH_-10mA (mV)']

w = 1/(Yerr**2)

# %%
sum_w = w.sum()
sum_wx = (w*X).sum()
sum_wy = (w*Y).sum()
sum_wxx = (w*X**2).sum()
sum_wxy = (w*X*Y).sum()

# %%
m = (sum_w*sum_wxy - sum_wx*sum_wy) / (sum_w*sum_wxx - sum_wx**2)
b = (sum_wxx*sum_wy - sum_wx*sum_wxy) / (sum_w*sum_wxx - sum_wx**2)

m_std_err = np.sqrt(sum_w/(sum_w*sum_wxx-sum_wx**2))
b_std_err = np.sqrt(sum_wxx/(sum_w*sum_wxx-sum_wx**2))

# %%
print(m)
print(b)

print(m_std_err)
print(b_std_err)
# Out:
# 0.06546247357127799
# 2.311059110286964
# 0.00013073119253263727
# 0.025820355543282828

# %%
model2 = (0.0656)*X + (2.31)

# %%
plt.errorbar(X, Y, Yerr, Xerr,  fmt='o')
plt.plot(X, model2, color = 'red', linestyle='--')
plt.title('Voltaje de Hall vs. Campo Magnético con ' + r'$I_p = -10mA$' + ' (Germanio n)')
plt.xlabel('Campo Magnético (mT)')
plt.ylabel('Voltaje de Hall (mV)')
plt.savefig('Icte_n_-10mA.png', format='png')

# %%
res = (Y - model2)/Yerr

fig2, (ax2) = plt.subplots(1, 1)

ax2.scatter(X, res)
ax2.axhline(0, color='green', linewidth=1, linestyle='--')

ax2.set_xlabel('Campo Magnético (mT)')
ax2.set_ylabel('Voltaje de Hall (mV)')
ax2.set_title('Residuales para Voltaje de Hall vs. Campo Magnético con ' + r'$I_p = -10mA$' + ' (Germanio n)')
ax2.grid()

plt.savefig('Icte_n_-10mA_residual.png', format='png')

# %%
Y = data['VH_10mA (mV)']

w = 1/(Yerr**2)

# %%
sum_w = w.sum()
sum_wx = (w*X).sum()
sum_wy = (w*Y).sum()
sum_wxx = (w*X**2).sum()
sum_wxy = (w*X*Y).sum()

# %%
m = (sum_w*sum_wxy - sum_wx*sum_wy) / (sum_w*sum_wxx - sum_wx**2)
b = (sum_wxx*sum_wy - sum_wx*sum_wxy) / (sum_w*sum_wxx - sum_wx**2)

m_std_err = np.sqrt(sum_w/(sum_w*sum_wxx-sum_wx**2))
b_std_err = np.sqrt(sum_wxx/(sum_w*sum_wxx-sum_wx**2))

# %%
print(m)
print(b)

print(m_std_err)
print(b_std_err)
# Out:
# -0.05050899268379618
# 0.5200289893534398
# 0.00013073119253263727
# 0.025820355543282828

# %%
model3 = (-0.0505)*X + (0.52)

# %%
plt.errorbar(X, Y, Yerr, Xerr,  fmt='o')
plt.plot(X, model3, color = 'red', linestyle='--')
plt.title('Voltaje de Hall vs. Campo Magnético con ' + r'$I_p = 10mA$' + ' (Germanio n)')
plt.xlabel('Campo Magnético (mT)')
plt.ylabel('Voltaje de Hall (mV)')
plt.savefig('Icte_n_10mA.png', format='png')

# %%
res = (Y - model3)/Yerr

fig2, (ax2) = plt.subplots(1, 1)

ax2.scatter(X, res)
ax2.axhline(0, color='green', linewidth=1, linestyle='--')

ax2.set_xlabel('Campo Magnético (mT)')
ax2.set_ylabel('Voltaje de Hall (mV)')
ax2.set_title('Residuales para Voltaje de Hall vs. Campo Magnético con ' + r'$I_p = 10mA$' + ' (Germanio n)')
ax2.grid()

plt.savefig('Icte_n_10mA_residual.png', format='png')

# %%
Y = data['VH_20mA (mV)']

w = 1/(Yerr**2)

# %%
sum_w = w.sum()
sum_wx = (w*X).sum()
sum_wy = (w*Y).sum()
sum_wxx = (w*X**2).sum()
sum_wxy = (w*X*Y).sum()

# %%
m = (sum_w*sum_wxy - sum_wx*sum_wy) / (sum_w*sum_wxx - sum_wx**2)
b = (sum_wxx*sum_wy - sum_wx*sum_wxy) / (sum_w*sum_wxx - sum_wx**2)

m_std_err = np.sqrt(sum_w/(sum_w*sum_wxx-sum_wx**2))
b_std_err = np.sqrt(sum_wxx/(sum_w*sum_wxx-sum_wx**2))

# %%
print(m)
print(b)

print(m_std_err)
print(b_std_err)
# Out:
# -0.10911978076363801
# 0.14377178030664325
# 0.00013073119253263727
# 0.025820355543282828

# %%
model4 = (-0.1091)*X + (0.14)

# %%
plt.errorbar(X, Y, Yerr, Xerr,  fmt='o')
plt.plot(X, model4, color = 'red', linestyle='--')
plt.title('Voltaje de Hall vs. Campo Magnético con ' + r'$I_p = 20mA$' + ' (Germanio n)')
plt.xlabel('Campo Magnético (mT)')
plt.ylabel('Voltaje de Hall (mV)')
plt.savefig('Icte_n_20mA.png', format='png')

# %%
res = (Y - model4)/Yerr

fig2, (ax2) = plt.subplots(1, 1)

ax2.scatter(X, res)
ax2.axhline(0, color='green', linewidth=1, linestyle='--')

ax2.set_xlabel('Campo Magnético (mT)')
ax2.set_ylabel('Voltaje de Hall (mV)')
ax2.set_title('Residuales para Voltaje de Hall vs. Campo Magnético con ' + r'$I_p = 10mA$' + ' (Germanio n)')
ax2.grid()

plt.savefig('Icte_n_20mA_residual.png', format='png')

# %%
m1 = 0.1258
m2 = 0.0656
m3 = -0.0505
m4 = -0.1091

# %%
plt.plot(X, model1, color = 'red', linestyle='--', label='-20mA' + '; m = ' + str(m1) + r'$\frac{mV}{mT}$')
plt.plot(X, model2, color = 'blue', linestyle='--', label='-10mA' + '; m = ' + str(m2) + r'$\frac{mV}{mT}$')
plt.plot(X, model3, color = 'green', linestyle='--', label='10mA' + '; m = ' + str(m3) + r'$\frac{mV}{mT}$')
plt.plot(X, model4, color = 'orange', linestyle='--', label='20mA' + '; m = ' + str(m4) + r'$\frac{mV}{mT}$')
plt.legend(loc='upper center')
plt.xlabel('Campo Magnético (mT)')
plt.ylabel('Voltaje de Hall (mV)')
plt.title('Voltaje de Hall vs. Campo Magnético con Corriente Constante (Germanio n)')
plt.savefig('Graficas Icte_n_Todas.png', format='png')

# %%
def calculateRH(m, I):
    w = 1e-3
    I = I/1000
    return m*w/I

# %%
def calculateRH_error(m, I, sigma_m, sigma_I):
    w = 1e-3
    I = I/1000
    sigma_I = sigma_I/1000
    error = np.sqrt( ( (w/I)*sigma_m )**2 + ( (m*w/(I**2))*sigma_I )**2 )
    
    return error

# %%
RH1 = calculateRH(m1, -20)
RH1_error = calculateRH_error(m1, -20, 0.0001, 1)

RH2 = calculateRH(m2, -10)
RH2_error = calculateRH_error(m2, -10, 0.0001, 1)

RH3 = calculateRH(m3, 10)
RH3_error = calculateRH_error(m3, 10, 0.0001, 1)

RH4 = calculateRH(m4, 20)
RH4_error = calculateRH_error(m4, 20, 0.0001, 1)

# %%
print(RH1)
print(RH1_error)
# Out:
# -0.00629
# 0.00031453974311682775

# %%
print(RH2)
print(RH2_error)
# Out:
# -0.006560000000000001
# 0.0006560762150848025

# %%
print(RH3)
print(RH3_error)
# Out:
# -0.00505
# 0.0005050990001969911

# %%
print(RH4)
print(RH4_error)
# Out:
# -0.005455000000000001
# 0.00027279582566454346

# %%
RH_array = [RH1, RH2, RH3, RH4]
I_array = [-20, -10, 10, 20]

# %%
plt.plot(I_array, RH_array)

# %%
average_RH = (RH1 + RH2 + RH3 + RH4)/4
average_RH_error = np.sqrt( (RH1_error/4)**2 + (RH2_error/4)**2 + (RH3_error/4)**2 + (RH4_error/4)**2 )

print(average_RH)
print(average_RH_error)
# Out:
# -0.00583875
# 0.0002316940078665178
