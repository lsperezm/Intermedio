# %% [markdown]
# ## Caracterización

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

data = "Datos_Bcte_n.xlsx"
data = pd.read_excel(data)
data
# Out:
#     I (mA)  I_err (mA)  VH_0.75A (mV)  VH_0.80A (mV)  VH_0.85A (mV)  \
# 0      -30           1           36.3           38.1           39.6
# 1      -25           1           31.2           31.6           34.9
# 2      -20           1           25.5           26.2           28.3
# 3      -15           1           19.6           20.3           21.4
# 4      -10           1           14.6           15.8           15.4
# 5       -5           1            9.0            9.1            9.3
# 6        0           1            3.5            3.9            1.1
# 7        5           1           -4.4           -4.0           -4.3
# 8       10           1           -9.3           -9.1           -9.9
# 9       15           1          -15.0          -15.0          -16.2
# 10      20           1          -18.9          -20.9          -22.2
# 11      25           1          -26.2          -26.9          -28.3
# 12      30           1          -31.1          -32.0          -35.4
#
#     VH_0.90A (mV)  VH_0.95A (mV)  VH_err (mV)
# 0            44.2           46.1          0.1
# 1            37.5           38.8          0.1
# 2            30.2           30.6          0.1
# 3            23.8           25.5          0.1
# 4            16.1           16.9          0.1
# 5            10.8            9.9          0.1
# 6             4.0            3.8          0.1
# 7            -4.2           -4.3          0.1
# 8           -10.4          -11.1          0.1
# 9           -17.1          -18.3          0.1
# 10          -24.7          -26.0          0.1
# 11          -31.1          -32.2          0.1
# 12          -36.9          -39.5          0.1

# %%
X = data['I (mA)']
Xerr = data['I_err (mA)']

Y = data['VH_0.75A (mV)']
Yerr = data['VH_err (mV)']

w = 1/(Yerr**2)

X
# Out:
# 0    -30
# 1    -25
# 2    -20
# 3    -15
# 4    -10
# 5     -5
# 6      0
# 7      5
# 8     10
# 9     15
# 10    20
# 11    25
# 12    30
# Name: I (mA), dtype: int64

# %%
sum_w = w.sum()
sum_wx = (w*X).sum()
sum_wy = (w*Y).sum()
sum_wxx = (w*X**2).sum()
sum_wxy = (w*X*Y).sum()

# %%
m = (sum_w*sum_wxy - sum_wx*sum_wy) / (sum_w*sum_wxx - sum_wx**2)
b = (sum_wxx*sum_wy - sum_wx*sum_wxy) / (sum_w*sum_wxx - sum_wx**2)

m_std_err = np.sqrt(sum_w/(sum_w*sum_wxx-sum_wx**2))
b_std_err = np.sqrt(sum_wxx/(sum_w*sum_wxx-sum_wx**2))

# %%
print(m)
print(b)

print(m_std_err)
print(b_std_err)
# Out:
# -1.1362637362637362
# 2.676923076923076
# 0.0014824986333222025
# 0.02773500981126146

# %%
model1 = (-1.136)*X + (2.68)

# %%
plt.errorbar(X, Y, Yerr, Xerr,  fmt='o')
plt.plot(X, model1, color = 'red', linestyle='--')
plt.title('Voltaje de Hall vs. Corriente con ' + r'$B = (170.22\pm 0.08)mT$' + ' (Germanio n)')
plt.xlabel('Corriente (mA)')
plt.ylabel('Voltaje de Hall (mV)')
plt.savefig('Bcte_n_0.75A.png', format='png')

# %%
res = (Y - model1)/Yerr

fig2, (ax2) = plt.subplots(1, 1)

ax2.scatter(X, res)
ax2.axhline(0, color='green', linewidth=1, linestyle='--')

ax2.set_xlabel('Corriente (mA)')
ax2.set_ylabel('Voltaje de Hall (mV)')
ax2.set_title('Residuales para Voltaje de Hall vs. Corriente con ' + r'$B = (170.22\pm 0.08)mT$' + ' (Germanio n)')
ax2.grid()

plt.savefig('Bcte_n_0.75A_residual.png', format='png')

# %%
Y = data['VH_0.80A (mV)']

w = 1/(Yerr**2)

# %%
sum_w = w.sum()
sum_wx = (w*X).sum()
sum_wy = (w*Y).sum()
sum_wxx = (w*X**2).sum()
sum_wxy = (w*X*Y).sum()

# %%
m = (sum_w*sum_wxy - sum_wx*sum_wy) / (sum_w*sum_wxx - sum_wx**2)
b = (sum_wxx*sum_wy - sum_wx*sum_wxy) / (sum_w*sum_wxx - sum_wx**2)

m_std_err = np.sqrt(sum_w/(sum_w*sum_wxx-sum_wx**2))
b_std_err = np.sqrt(sum_wxx/(sum_w*sum_wxx-sum_wx**2))

# %%
print(m)
print(b)

print(m_std_err)
print(b_std_err)
# Out:
# -1.1761538461538463
# 2.8538461538461544
# 0.0014824986333222025
# 0.02773500981126146

# %%
model2 = (-1.176)*X + (2.85)

# %%
plt.errorbar(X, Y, Yerr, Xerr,  fmt='o')
plt.plot(X, model2, color = 'red', linestyle='--')
plt.title('Voltaje de Hall vs. Corriente con ' + r'$B = (181.65\pm 0.09)mT$' + ' (Germanio n)')
plt.xlabel('Corriente (mA)')
plt.ylabel('Voltaje de Hall (mV)')
plt.savefig('Bcte_n_0.80A.png', format='png')

# %%
res = (Y - model2)/Yerr

fig2, (ax2) = plt.subplots(1, 1)

ax2.scatter(X, res)
ax2.axhline(0, color='green', linewidth=1, linestyle='--')

ax2.set_xlabel('Corriente (mA)')
ax2.set_ylabel('Voltaje de Hall (mV)')
ax2.set_title('Residuales para Voltaje de Hall vs. Corriente con ' + r'$B = (181.65\pm 0.09)mT$' + ' (Germanio n)')
ax2.grid()

plt.savefig('Bcte_n_0.80A_residual.png', format='png')

# %%
Y = data['VH_0.85A (mV)']

w = 1/(Yerr**2)

# %%
sum_w = w.sum()
sum_wx = (w*X).sum()
sum_wy = (w*Y).sum()
sum_wxx = (w*X**2).sum()
sum_wxy = (w*X*Y).sum()

# %%
m = (sum_w*sum_wxy - sum_wx*sum_wy) / (sum_w*sum_wxx - sum_wx**2)
b = (sum_wxx*sum_wy - sum_wx*sum_wxy) / (sum_w*sum_wxx - sum_wx**2)

m_std_err = np.sqrt(sum_w/(sum_w*sum_wxx-sum_wx**2))
b_std_err = np.sqrt(sum_wxx/(sum_w*sum_wxx-sum_wx**2))

# %%
print(m)
print(b)

print(m_std_err)
print(b_std_err)
# Out:
# -1.2582417582417584
# 2.592307692307693
# 0.0014824986333222025
# 0.02773500981126146

# %%
model3 = (-1.258)*X + (2.59)

# %%
plt.errorbar(X, Y, Yerr, Xerr,  fmt='o')
plt.plot(X, model3, color = 'red', linestyle='--')
plt.title('Voltaje de Hall vs. Corriente con ' + r'$B = (193.08\pm 0.09)mT$' + ' (Germanio n)')
plt.xlabel('Corriente (mA)')
plt.ylabel('Voltaje de Hall (mV)')
plt.savefig('Bcte_n_0.85A.png', format='png')

# %%
res = (Y - model3)/Yerr

fig2, (ax2) = plt.subplots(1, 1)

ax2.scatter(X, res)
ax2.axhline(0, color='green', linewidth=1, linestyle='--')

ax2.set_xlabel('Corriente (mA)')
ax2.set_ylabel('Voltaje de Hall (mV)')
ax2.set_title('Residuales para Voltaje de Hall vs. Corriente con ' + r'$B = (193.08\pm 0.09)mT$' + ' (Germanio n)')
ax2.grid()

plt.savefig('Bcte_n_0.85A_residual.png', format='png')

# %%
Y = data['VH_0.90A (mV)']

w = 1/(Yerr**2)

# %%
sum_w = w.sum()
sum_wx = (w*X).sum()
sum_wy = (w*Y).sum()
sum_wxx = (w*X**2).sum()
sum_wxy = (w*X*Y).sum()

# %%
m = (sum_w*sum_wxy - sum_wx*sum_wy) / (sum_w*sum_wxx - sum_wx**2)
b = (sum_wxx*sum_wy - sum_wx*sum_wxy) / (sum_w*sum_wxx - sum_wx**2)

m_std_err = np.sqrt(sum_w/(sum_w*sum_wxx-sum_wx**2))
b_std_err = np.sqrt(sum_wxx/(sum_w*sum_wxx-sum_wx**2))

# %%
print(m)
print(b)

print(m_std_err)
print(b_std_err)
# Out:
# -1.362527472527473
# 3.246153846153848
# 0.0014824986333222025
# 0.02773500981126146

# %%
model4 = (-1.363)*X + (3.25)

# %%
plt.errorbar(X, Y, Yerr, Xerr,  fmt='o')
plt.plot(X, model4, color = 'red', linestyle='--')
plt.title('Voltaje de Hall vs. Corriente con ' + r'$B = (204.5\pm 0.1)mT$' + ' (Germanio n)')
plt.xlabel('Corriente (mA)')
plt.ylabel('Voltaje de Hall (mV)')
plt.savefig('Bcte_n_0.90A.png', format='png')

# %%
res = (Y - model4)/Yerr

fig2, (ax2) = plt.subplots(1, 1)

ax2.scatter(X, res)
ax2.axhline(0, color='green', linewidth=1, linestyle='--')

ax2.set_xlabel('Corriente (mA)')
ax2.set_ylabel('Voltaje de Hall (mV)')
ax2.set_title('Residuales para Voltaje de Hall vs. Corriente con ' + r'$B = (204.5\pm 0.1)mT$' + ' (Germanio n)')
ax2.grid()

plt.savefig('Bcte_n_0.90A_residual.png', format='png')

# %%
Y = data['VH_0.95A (mV)']

w = 1/(Yerr**2)

# %%
sum_w = w.sum()
sum_wx = (w*X).sum()
sum_wy = (w*Y).sum()
sum_wxx = (w*X**2).sum()
sum_wxy = (w*X*Y).sum()

# %%
m = (sum_w*sum_wxy - sum_wx*sum_wy) / (sum_w*sum_wxx - sum_wx**2)
b = (sum_wxx*sum_wy - sum_wx*sum_wxy) / (sum_w*sum_wxx - sum_wx**2)

m_std_err = np.sqrt(sum_w/(sum_w*sum_wxx-sum_wx**2))
b_std_err = np.sqrt(sum_wxx/(sum_w*sum_wxx-sum_wx**2))

# %%
print(m)
print(b)

print(m_std_err)
print(b_std_err)
# Out:
# -1.4248351648351647
# 3.0923076923076915
# 0.0014824986333222025
# 0.02773500981126146

# %%
model5 = (-1.425)*X + (3.09)

# %%
plt.errorbar(X, Y, Yerr, Xerr,  fmt='o')
plt.plot(X, model5, color = 'red', linestyle='--')
plt.title('Voltaje de Hall vs. Corriente con ' + r'$B = (215.9\pm 0.1)mT$' + ' (Germanio n)')
plt.xlabel('Corriente (mA)')
plt.ylabel('Voltaje de Hall (mV)')
plt.savefig('Bcte_n_0.95A.png', format='png')

# %%
res = (Y - model5)/Yerr

fig2, (ax2) = plt.subplots(1, 1)

ax2.scatter(X, res)
ax2.axhline(0, color='green', linewidth=1, linestyle='--')

ax2.set_xlabel('Corriente (mA)')
ax2.set_ylabel('Voltaje de Hall (mV)')
ax2.set_title('Residuales para Voltaje de Hall vs. Corriente con ' + r'$B = (215.9\pm 0.1)mT$' + ' (Germanio n)')
ax2.grid()

plt.savefig('Bcte_n_0.95A_residual.png', format='png')

# %%
m1 = -1.136
m2 = -1.176
m3 = -1.258
m4 = -1.363
m5 = -1.425

# %%
plt.plot(X, model1, color = 'red', linestyle='--', label = '170.22mT' + '; m = ' + str(m1) + r'$\frac{mV}{mA}$')
plt.plot(X, model2, color = 'blue', linestyle='--', label = '181.65mT' + '; m = ' + str(m2) + r'$\frac{mV}{mA}$')
plt.plot(X, model3, color = 'green', linestyle='--', label = '193.08mT' + '; m = ' + str(m3) + r'$\frac{mV}{mA}$')
plt.plot(X, model4, color = 'orange', linestyle='--', label = '204.5mT' + '; m = ' + str(m4) + r'$\frac{mV}{mA}$')
plt.plot(X, model5, color = 'magenta', linestyle='--', label = '215.9mT' + '; m = ' + str(m5) + r'$\frac{mV}{mA}$')
plt.legend(loc='upper right')
plt.xlabel("Corriente (mA)")
plt.ylabel("Voltaje de Hall (mV)")
plt.title("Voltaje de Hall vs. Corriente con Campo Magnético Constante (Germanio n)")
plt.savefig("Graficas Bcte_n_Todas.png", format='png')

# %%
def calculateRH(m, B):
    w = 1e-3
    B = B/1000
    return m*w/B

# %%
def calculateRH_error(m, B, sigma_m, sigma_B):
    w = 1e-3
    B = B/1000
    sigma_B = sigma_B/1000
    error = np.sqrt( ( (w/B)*sigma_m )**2 + ( (m*w/(B**2))*sigma_B )**2 )
    
    return error

# %%
RH1 = calculateRH(m1, 170.22)
RH1_error = calculateRH_error(m1, 170.22, 0.002, 0.08)

RH2 = calculateRH(m2, 181.65)
RH2_error = calculateRH_error(m2, 181.65, 0.002, 0.09)

RH3 = calculateRH(m3, 193.08)
RH3_error = calculateRH_error(m3, 193.08, 0.002, 0.09)

RH4 = calculateRH(m4, 204.5)
RH4_error = calculateRH_error(m4, 204.5, 0.002, 0.1)

RH5 = calculateRH(m5, 215.9)
RH5_error = calculateRH_error(m5, 215.9, 0.002, 0.1)

# %%
print(RH1)
print(RH1_error)
# Out:
# -0.006673716367054399
# 1.216094082238714e-05

# %%
print(RH2)
print(RH2_error)
# Out:
# -0.006473988439306358
# 1.1467903161407646e-05

# %%
print(RH3)
print(RH3_error)
# Out:
# -0.006515434016987777
# 1.0794442726741492e-05

# %%
print(RH4)
print(RH4_error)
# Out:
# -0.006665036674816626
# 1.0308721601868545e-05

# %%
print(RH5)
print(RH5_error)
# Out:
# -0.006600277906438166
# 9.754956586876324e-06

# %%
RH_array = [RH1, RH2, RH3, RH4, RH5]
B_array = [170.22, 181.65, 193.08, 204.5, 215.9]

# %%
plt.plot(B_array, RH_array)

# %%
average_RH = (RH1 + RH2 + RH3 + RH4 + RH5)/5
average_RH_error = np.sqrt( (RH1_error/5)**2 + (RH2_error/5)**2 + (RH3_error/5)**2 + (RH4_error/5)**2 + (RH5_error/5)**2 )

print(average_RH)
print(average_RH_error)
# Out:
# -0.0065856906809206636
# 4.888149741825022e-06
