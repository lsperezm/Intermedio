# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

data = "Datos_VL_p.xlsx"
data = pd.read_excel(data)
data
# Out:
#     CorrienteCampo (A)  B (mT)  B_err (mT)  B_rounded (mT)  \
# 0                 -1.4 -321.16    0.135558         -321.20
# 1                 -1.2 -275.45    0.119013         -275.50
# 2                 -1.0 -229.74    0.102956         -229.70
# 3                 -0.8 -184.03    0.087658         -184.03
# 4                 -0.6 -138.32    0.073593         -138.32
# 5                 -0.4  -92.61    0.061612          -92.61
# 6                 -0.2  -46.90    0.053141          -46.90
# 7                  0.0   -1.19    0.050000           -1.19
# 8                  0.2   44.52    0.053141           44.52
# 9                  0.4   90.23    0.061612           90.23
# 10                 0.6  135.94    0.073593          135.94
# 11                 0.8  181.65    0.087658          181.65
# 12                 1.0  227.36    0.102956          227.40
# 13                 1.2  273.07    0.119013          273.10
# 14                 1.4  318.78    0.135558          318.80
#
#     B_err_rounded (mT)  VL_-20mA (mV)  VL_-10mA (mV)  VL_10mA (mV)  \
# 0                 0.10          0.747          0.392         0.346
# 1                 0.10          0.742          0.390         0.344
# 2                 0.10          0.738          0.387         0.342
# 3                 0.09          0.734          0.386         0.340
# 4                 0.07          0.731          0.384         0.339
# 5                 0.06          0.729          0.383         0.338
# 6                 0.05          0.728          0.383         0.338
# 7                 0.05          0.732          0.387         0.337
# 8                 0.05          0.732          0.386         0.338
# 9                 0.06          0.732          0.387         0.338
# 10                0.07          0.734          0.387         0.339
# 11                0.09          0.737          0.388         0.341
# 12                0.10          0.740          0.390         0.343
# 13                0.10          0.744          0.392         0.345
# 14                0.10          0.749          0.394         0.343
#
#     VL_20mA (mV)  VL_err (mV)
# 0          0.664          0.1
# 1          0.660          0.1
# 2          0.656          0.1
# 3          0.653          0.1
# 4          0.650          0.1
# 5          0.648          0.1
# 6          0.647          0.1
# 7          0.646          0.1
# 8          0.647          0.1
# 9          0.648          0.1
# 10         0.650          0.1
# 11         0.653          0.1
# 12         0.657          0.1
# 13         0.661          0.1
# 14         0.665          0.1

# %%
X = data['B_rounded (mT)']
Xerr = data['B_err_rounded (mT)']

# %% [markdown]
# Ip = -20mA

# %%
Y = data['VL_-20mA (mV)']
Yerr = data['VL_err (mV)']

# %%
R0 = 0.732/20

Rm = Y/20

plot1 = ( (Rm-R0)/R0 )

plt.plot(X, plot1)

# %% [markdown]
# Ip = -10mA

# %%
Y = data['VL_-10mA (mV)']

# %%
R0 = 0.387/10

Rm = Y/10

plot2 = ( (Rm-R0)/R0 )

plt.plot(X, plot2)

# %%
Y = data['VL_10mA (mV)']

# %%
R0 = 0.337/10

Rm = Y/10

plot3 = ( (Rm-R0)/R0 )

plt.plot(X, plot3)

# %%
Y = data['VL_20mA (mV)']

# %%
R0 = 0.646/20

Rm = Y/20

plot4 = ( (Rm-R0)/R0 )

plt.plot(X, plot4)
